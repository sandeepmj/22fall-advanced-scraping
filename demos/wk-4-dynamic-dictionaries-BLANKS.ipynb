# %%
pip install icecream

# %%
from icecream import ic

# %%
## a basic dict

# %%
## add to that dict

# %%
## we have list of dates in a dict
dates = [{'date': 'January 2021'},  {'date': 'February 2021'}, {'date': 'March 2021'}, ]

# %%
## we scrape some values
values = [1, 2, 3]

# %%
## we scrape some labels
labels = ["a", "b", "c"]

# %% [markdown]
# ## Build a list of dictionaries in which each value is incremented for each label. It doesn't matter much by how much it is incremented. We just want the value to change in some way:
#
# It could be this result:
#
# ```
# [{'date': 'January 2021', 'a': 3, 'b': 3, 'c': 3},
#  {'date': 'February 2021', 'a': 6, 'b': 6, 'c': 6},
#  {'date': 'March 2021', 'a': 9, 'b': 9, 'c': 9}]
# ```
#
# Or even:
#
# ```
# [{'a': 3, 'b': 6, 'c': 9, 'date': 'January 2021'},
#  {'a': 12, 'b': 15, 'c': 18, 'date': 'February 2021'},
#  {'a': 21, 'b': 24, 'c': 27, 'date': 'March 2021'}]
#  ```
# ```

# %%
## build it here
